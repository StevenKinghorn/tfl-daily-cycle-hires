# %%
! pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.42.59-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.43.0,>=1.42.59 (from boto3)
#   Downloading botocore-1.42.59-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/computer/Documents/JupyterProjects/tfl-daily-cycle-hires/venv/tfl-venv/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.59->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/computer/Documents/JupyterProjects/tfl-daily-cycle-hires/venv/tfl-venv/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.59->boto3) (2.6.3)
# Requirement already satisfied: six>=1.5 in /home/computer/Documents/JupyterProjects/tfl-daily-cycle-hires/venv/tfl-venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.59->boto3) (1.17.0)
# Downloading boto3-1.42.59-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 4.0 MB/s eta 0:00:005.1 MB/s eta 0:00:01
# Downloading botocore-1.42.59-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 8.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.59 botocore-1.42.59 jmespath-1.1.0 s3transfer-0.16.0

# %%
import boto3
import os
import json
from botocore import UNSIGNED
from botocore.config import Config

# %%
# Number of csv files to download for this project
csv_no = 2 #Two files for this test case
s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))

def download_from_config(config_path):
    i = 0
    with open(config_path, 'r') as file:
        data = json.load(file) 

    for entry in data['entries']:
        s3_url = entry['url']
        clean_url =s3_url.replace("s3://", "")
        bucket_name, key = clean_url.split("/", 1)
        filename = os.path.basename(key)
        i = i + 1
        
        print(f"Downloading file {i} of {csv_no}:  {filename}")
        try:
            #s3.download_file(bucket_name, key, f"../data/tfl-cycling-journey-data-2024-2025/raw-test/{filename}")
            #print(f"Done: ../data/tfl-cycling-journey-data-2024-2025/raw-test/{filename}")
            s3.download_file(bucket_name, key, filename)
            print(f"Done: {filename}")
        except Exception as e:
            print(f"Error downloading {filename}: {e}")
        
        
if __name__ == "__main__":
    #print(f"WARNING: Download size is quite large ({csv_no} .csv files, ~2.8G) and may take some time.")
    print(f"WARNING: Download size is quite large ({csv_no} .csv files) and may take some time.")
    user_input = input("Are you sure you want to continue? (Y,n)").strip().lower()

    if user_input in ['y', 'yes', '']:
        file_path = "../json/config.json"
        download_from_config(file_path)
    else:
        print("Download cancelled.")
# Out:
# WARNING: Download size is quite large (2 .csv files) and may take some time.
# Are you sure you want to continue? (Y,n)
# Downloading file 1 of 2:  01aJourneyDataExtract10Jan16-23Jan16.csv
# Done: 01aJourneyDataExtract10Jan16-23Jan16.csv
# Downloading file 2 of 2:  01bJourneyDataExtract24Jan16-06Feb16.csv
# Done: 01bJourneyDataExtract24Jan16-06Feb16.csv
